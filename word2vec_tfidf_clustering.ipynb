# %%
import os
import numpy as np
import pandas as pd

from url_sequences.sequence_manager import *
from url_sequences.sequence_plotter import *
from url_sequences.sequence_handler import *
from url_sequences.clustering_metrics import *

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE

from sklearn.cluster import KMeans
from hdbscan import HDBSCAN

import plotly.plotly as py
from plotly.graph_objs import *
import plotly.graph_objs as go

from gensim.models import Word2Vec

# %% [markdown]
# ### Loading no-costraint & list-costraint Dataset
# - **content_nc_map** -> dict {code: content_string}
# - **url_nc_map** -> dict {code: longurl}
# - **pages_content_nc** -> list [content strings]
# - **codes_nc** -> list [codes]
# - **longurls_nc** -> list [longurls]

# %%
"""Real membership List"""
rm = RealMembership()  


"""No-Costraint"""
nocostraint_path   = os.getcwd() + "/dataset/new/cs.illinois.eduNoConstraint.words1000.depth.10/"
vertex_nc_path     = nocostraint_path + "vertex.txt"
map_nc_path        = nocostraint_path + "urlsMap.txt"

# code -> content_string - dict 
content_nc_map = get_content_map(vertex_nc_path)
# code -> longurl - dict 
url_nc_map = get_urlmap(map_nc_path)
# document no-costraint list
pages_content_nc = [content_nc_map[key] for key in content_nc_map]
# codes no-costraint list
codes_nc = [key for key in content_nc_map]
# longurls no-costraint list
longurls_nc = [url_nc_map[key] for key in content_nc_map]
# real membership list-costraint
real_membership_nc = [rm.get_membership(url_nc_map[key]) for key in content_nc_map]

"""List-Costraint"""
listcostraint_path = os.getcwd() + "/dataset/new/cs.illinois.edu.ListConstraint.words1000.depth10/"
vertex_lc_path     = listcostraint_path + "vertex.txt"
map_lc_path        = listcostraint_path + "urlsMap.txt"

# code -> content_string - dict 
content_lc_map = get_content_map(vertex_lc_path)
# code -> longurl - dict 
url_lc_map = get_urlmap(map_lc_path)
# document list-costraint list
pages_content_lc = [content_lc_map[key] for key in content_lc_map]
# codes list-costraint list
codes_lc = [key for key in content_lc_map]
# longurls list-costraint list
longurls_lc = [url_lc_map[key] for key in content_lc_map]
# real membership list-costraint
real_membership_lc = [rm.get_membership(url_lc_map[key]) for key in content_lc_map]
# Out:
# ['http://cs.illinois.edu/', '-1\n']
# ['http://cs.illinois.edu/', '-1\n']
# ['http://cs.illinois.edu/45.55.227.170/', '-1\n']
# ['http://cs.illinois.edu/about-us/', '-1\n']
# ['http://cs.illinois.edu/about-us/about-siebel-center/', '-1\n']
# ['http://cs.illinois.edu/about-us/awards/', '-1\n']
# ['http://cs.illinois.edu/about-us/awards/best-paper-awards/', '-1\n']
# ['http://cs.illinois.edu/about-us/awards/distinguished-alumni/', '-1\n']
# ['http://cs.illinois.edu/about-us/awards/distinguished-alumni/2011-distinguished-achievement-award/', '0\n']
# ['http://cs.illinois.edu/about-us/awards/distinguished-alumni/2011-distinguished-educator-award/', '0\n']
# ['http://cs.illinois.edu/about-us/awards/distinguished-alumni/2011-distinguished-service-award/', '0\n']
# ['http://cs.illinois.edu/about-us/awards/distinguished-alumni/2011-memorial-achievement-award/', '0\n']
# ['http://cs.illinois.edu/about-us/awards/distinguished-alumni/2012-distinguished-achievement-award/', '0\n']
# ['http://cs.illinois.edu/about-us/awards/distinguished-alumni/2012-distinguished-educator-award/', '0\n']
# ['http://cs.illinois.edu/about-us/awards/distinguished-alumni/2012-distinguished-service-award/', '0\n']
# ['http://cs.illinois.edu/about-us/awards/distinguished-alumni/2013-distinguished-achievement-award/', '0\n']
# ['http://cs.illinois.edu/about-us/awards/distinguished-alumni/2013-distinguished-educator-award/', '0\n']
# ['http://cs.illinois.edu/about-us/awards/distinguished-alumni/2013-distinguished-service-award/', '0\n']
# ['http://cs.illinois.edu/about-us/awards/distinguished-alumni/2014-distinguished-achievement-award/', '0\n']
# ['http://cs.illinois.edu/about-us/awards/distinguished-alumni/2014-distinguished-educator-award/', '0\n']
# ['http://cs.illinois.edu/about-us/awards/distinguished-alumni/2014-distinguished-service-award/', '0\n']
# ['http://cs.illinois.edu/about-us/awards/distinguished-alumni/2015-distinguished-achievement-award/', '0\n']
# ['http://cs.illinois.edu/about-us/awards/distinguished-alumni/2015-distinguished-educator-award/', '0\n']
# ['http://cs.illinois.edu/about-us/awards/distinguished-alumni/2015-distinguished-service-award/', '0\n']
# ['http://cs.illinois.edu/about-us/awards/distinguished-alumni/nationally-internationally-recognized-alumni/', '0\n']
# ['http://cs.illinois.edu/about-us/awards/distinguished-alumni/university-illinois-alumni-awards/', '0\n']
# ['http://cs.illinois.edu/about-us/awards/faculty-awards/', '-1\n']
# ['http://cs.illinois.edu/about-us/awards/faculty-awards/chairs-professorships/', '1\n']
# ['http://cs.illinois.edu/about-us/awards/faculty-awards/chairs-professorships/abel-bliss-professorship-engineering/', '1\n']
# ['http://cs.illinois.edu/about-us/awards/faculty-awards/chairs-professorships/donald-b-gillies-chair-computer-science/', '1\n']
# ['http://cs.illinois.edu/about-us/awards/faculty-awards/chairs-professorships/donald-biggar-willett-professorship-engineering/', '1\n']
# ['http://cs.illinois.edu/about-us/awards/faculty-awards/chairs-professorships/founder-professorship-engineering/', '1\n']
# ['http://cs.illinois.edu/about-us/awards/faculty-awards/chairs-professorships/fulton-watson-copp-chair-computer-science/', '1\n']
# ['http://cs.illinois.edu/about-us/awards/faculty-awards/chairs-professorships/michael-faiman-and-saburo-muroga-professorship-/', '1\n']
# ['http://cs.illinois.edu/about-us/awards/faculty-awards/chairs-professorships/paul-and-cynthia-saylor-professorship-computer-/', '1\n']
# ['http://cs.illinois.edu/about-us/awards/faculty-awards/chairs-professorships/ralph-m-and-catherine-v-fisher-professorship/', '1\n']
# ['http://cs.illinois.edu/about-us/awards/faculty-awards/chairs-professorships/sohaib-and-sara-abbasi-professorship-computer-s/', '1\n']
# ['http://cs.illinois.edu/about-us/awards/faculty-awards/chairs-professorships/thomas-m-siebel-chair-computer-science/', '1\n']
# ['http://cs.illinois.edu/about-us/awards/faculty-awards/illinois-faculty-awards/', '1\n']
# ['http://cs.illinois.edu/about-us/awards/past-recipients/', '-1\n']
# ['http://cs.illinois.edu/about-us/awards/staff-awards/', '-1\n']
# ['http://cs.illinois.edu/about-us/cs-history/', '-1\n']
# ['http://cs.illinois.edu/about-us/cs-history/cs-50/', '-1\n']
# ['http://cs.illinois.edu/about-us/cs-history/cs-history-timeline/', '-1\n']
# ['http://cs.illinois.edu/about-us/cs-statistics/', '-1\n']
# ['http://cs.illinois.edu/about-us/directions-siebel-center/', '-1\n']
# ['http://cs.illinois.edu/about-us/resources/', '-1\n']
# ['http://cs.illinois.edu/about-us/why-illinois/', '-1\n']
# ['http://cs.illinois.edu/alumni/', '-1\n']
# ['http://cs.illinois.edu/alumni/alumni-news-archive/', '-1\n']
# ['http://cs.illinois.edu/alumni/alumni-profiles/', '-1\n']
# ['http://cs.illinois.edu/alumni/stay-touch/', '-1\n']
# ['http://cs.illinois.edu/alumni/stayintouch/', '-1\n']
# ['http://cs.illinois.edu/compgen.illinois.edu/', '-1\n']
# ['http://cs.illinois.edu/content/illinois-faculty-developing-mobile-learning-community/', '-1\n']
# ['http://cs.illinois.edu/courses.illinois.edu/catalog/CS/103.html/', '-1\n']
# ['http://cs.illinois.edu/courses.illinois.edu/schedule/DEFAULT/DEFAULT/CS/450/', '-1\n']
# ['http://cs.illinois.edu/courses/', '-1\n']
# ['http://cs.illinois.edu/courses/full-curriculum/', '-1\n']
# ['http://cs.illinois.edu/courses/profile/-120158CS100/', '2\n']
# ['http://cs.illinois.edu/courses/profile/-120158CS101/', '2\n']
# ['http://cs.illinois.edu/courses/profile/-120158CS102/', '2\n']
# ['http://cs.illinois.edu/courses/profile/-120158CS103/', '2\n']
# ['http://cs.illinois.edu/courses/profile/-120158CS105/', '2\n']
# ['http://cs.illinois.edu/courses/profile/-120158CS125/', '2\n']
# ['http://cs.illinois.edu/courses/profile/-120158CS173/', '2\n']
# ['http://cs.illinois.edu/courses/profile/-120158CS225/', '2\n']
# ['http://cs.illinois.edu/courses/profile/-120158CS357/', '2\n']
# ['http://cs.illinois.edu/courses/profile/-120158ECE190/', '2\n']
# ['http://cs.illinois.edu/courses/profile/-120158MATH213/', '2\n']
# ['http://cs.illinois.edu/courses/profile/-120158MATH220/', '2\n']
# ['http://cs.illinois.edu/courses/profile/-120158MATH221/', '2\n']
# ['http://cs.illinois.edu/courses/profile/-120158MATH225/', '2\n']
# ['http://cs.illinois.edu/courses/profile/-120158MATH234/', '2\n']
# ['http://cs.illinois.edu/courses/profile/-120158MATH241/', '2\n']
# ['http://cs.illinois.edu/courses/profile/-120158MATH285/', '2\n']
# ['http://cs.illinois.edu/courses/profile/-120158MATH415/', '2\n']
# ['http://cs.illinois.edu/courses/profile////MATH221/', '2\n']
# ['http://cs.illinois.edu/courses/profile///CS100/', '2\n']
# ['http://cs.illinois.edu/courses/profile///CS101/', '2\n']
# ['http://cs.illinois.edu/courses/profile///CS102/', '2\n']
# ['http://cs.illinois.edu/courses/profile///CS103/', '2\n']
# ['http://cs.illinois.edu/courses/profile///CS105/', '2\n']
# ['http://cs.illinois.edu/courses/profile///CS125/', '2\n']
# ['http://cs.illinois.edu/courses/profile///CS173/', '2\n']
# ['http://cs.illinois.edu/courses/profile///ECE190/', '2\n']
# ['http://cs.illinois.edu/courses/profile///MATH213/', '2\n']
# ['http://cs.illinois.edu/courses/profile///MATH220/', '2\n']
# ['http://cs.illinois.edu/courses/profile///MATH221/', '2\n']
# ['http://cs.illinois.edu/courses/profile///MATH225/', '2\n']
# ['http://cs.illinois.edu/courses/profile///MATH231/', '2\n']
# ['http://cs.illinois.edu/courses/profile///MATH234/', '2\n']
# ['http://cs.illinois.edu/courses/profile///MATH241/', '2\n']
# ['http://cs.illinois.edu/courses/profile///MATH415/', '2\n']
# ['http://cs.illinois.edu/courses/profile//CS100/', '2\n']
# ['http://cs.illinois.edu/courses/profile//CS101/', '2\n']
# ['http://cs.illinois.edu/courses/profile//CS102/', '2\n']
# ['http://cs.illinois.edu/courses/profile//CS103/', '2\n']
# ['http://cs.illinois.edu/courses/profile//CS105/', '2\n']
# ['http://cs.illinois.edu/courses/profile//CS125/', '2\n']
# ['http://cs.illinois.edu/courses/profile//CS173/', '2\n']
# ['http://cs.illinois.edu/courses/profile//CS225/', '2\n']
# ['http://cs.illinois.edu/courses/profile//CS357/', '2\n']
# ['http://cs.illinois.edu/courses/profile//ECE190/', '2\n']
# ['http://cs.illinois.edu/courses/profile//MATH213/', '2\n']
# ['http://cs.illinois.edu/courses/profile//MATH220/', '2\n']
# ['http://cs.illinois.edu/courses/profile//MATH221/', '2\n']
# ['http://cs.illinois.edu/courses/profile//MATH225/', '2\n']
# ['http://cs.illinois.edu/courses/profile//MATH234/', '2\n']
# ['http://cs.illinois.edu/courses/profile//MATH241/', '2\n']
# ['http://cs.illinois.edu/courses/profile//MATH285/', '2\n']
# ['http://cs.illinois.edu/courses/profile//MATH415/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS100-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS100/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS101-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS101/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS102/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS103/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS105-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS105/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS125-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS125/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS173-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS173/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS196-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS196/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS199-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS199/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS199G1H-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS199G1H/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS199PUR-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS199PUR/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS210-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS210/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS225-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS225/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS231/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS232/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS233-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS233/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS241-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS241/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS242-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS242/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS296-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS296/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS357-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS357/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS410/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS411-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS411/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS412-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS412/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS413-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS413/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS414/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS418-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS418/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS419/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS420-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS420/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS421-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS421/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS422/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS423/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS424/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS425-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS425/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS426-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS426/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS427-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS427/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS428/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS429/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS431-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS431/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS433-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS433/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS438-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS438/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS439-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS439/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS440-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS440/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS446-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS446/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS447-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS447/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS450-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS450/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS458/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS461-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS461/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS463/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS465-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS465/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS473/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS475/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS476-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS476/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS477-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS477/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS481-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS481/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS483-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS483/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS491-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS491/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS492-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS492/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS493/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS494/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498AB2-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498AB2/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498AL1-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498AL1/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498BL1-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498BL1/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498CL1-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498CL1/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498DL1-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498DL1/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498GFD-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498GFD/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498IDS-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498IDS/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498MP3-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498MP3/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498OSP-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498OSP/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498SL3-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498SL3/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498SL4-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS498SL4/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS499/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS519-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS519/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS527-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS527/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS541-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS541/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS549-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS549/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS554-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS554/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS565-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS565/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS571-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS571/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS572-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS572/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS574-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS574/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS575-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS575/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591ACT-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591ACT/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591BIO-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591BIO/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591CCR-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591CCR/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591FM-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591FM/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591GFX-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591GFX/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591HCI-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591HCI/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591IG-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591IG/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591MH-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591MH/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591PHD-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591PHD/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591RHC-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591RHC/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591SE-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591SE/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591TA-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591TA/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591TCS-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS591TCS/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598AGP-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598AGP/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598AK-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598AK/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598APK-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598APK/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598DAF-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598DAF/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598DHP-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598DHP/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598HS-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598HS/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598JGE-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598JGE/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598JP-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598JP/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598KGK-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598KGK/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598MP-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598MP/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598PS-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598PS/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598RK-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598RK/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598TAR-120158/', '2\n']
# ['http://cs.illinois.edu/courses/profile/CS598TAR/', '2\n']
# ['http://cs.illinois.edu/courses/profile/ECE190/', '2\n']
# ['http://cs.illinois.edu/courses/profile/MATH213/', '2\n']
# ['http://cs.illinois.edu/courses/profile/MATH220/', '2\n']
# ['http://cs.illinois.edu/courses/profile/MATH221/', '2\n']
# ['http://cs.illinois.edu/courses/profile/MATH225/', '2\n']
# ['http://cs.illinois.edu/courses/profile/MATH231/', '2\n']
# ['http://cs.illinois.edu/courses/profile/MATH234/', '2\n']
# ['http://cs.illinois.edu/courses/profile/MATH241/', '2\n']
# ['http://cs.illinois.edu/courses/profile/MATH285/', '2\n']
# ['http://cs.illinois.edu/courses/profile/MATH415/', '2\n']
# ['http://cs.illinois.edu/cs.illinois.edu/courses/profile/CS499/', '-1\n']
# ['http://cs.illinois.edu/current-students/', '-1\n']
# ['http://cs.illinois.edu/current-students/counseling-resources/', '-1\n']
# ['http://cs.illinois.edu/current-students/graduate-students/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/bs-mcs-5-year-program/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/bs-ms-5-year-program/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/general-policies-and-processes/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/general-policies-processes-and-forms/graduate-student-self-evalua/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/graduate-advising/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/graduate-courses/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/international-students-epi-exam-cpt-opt/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/international-students-epi-exam-cpt-opt/cpt-application-process/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/international-students-epi-exam-cpt-opt/epi-exam-requirements/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/international-students-epi-exam-cpt-opt/opt-training-process/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/ms-bioinformatics/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/ms-thesis/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/new-graduate-student-orientation/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/official-forms/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/phd-students/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/phd-students/guidelines-forming-phd-committee/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/phd-students/phd-final-exam-thesis-defense/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/phd-students/phd-ms-thesis-format-review-guidelines/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/phd-students/phd-prelim-exam-thesis-proposal/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/phd-students/phd-program-study-process/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/phd-students/phd-program-study-process/program-study-course-recom/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/phd-students/phd-qualifying-exam/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/phd-students/phd-requirements/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/phd-students/phd-time-requirements-and-milestones/', '3\n']
# ['http://cs.illinois.edu/current-students/graduate-students/professional-masters-mcs/', '3\n']
# ['http://cs.illinois.edu/current-students/new-graduate-student-orientation/incoming-ms/', '3\n']
# ['http://cs.illinois.edu/current-students/new-graduate-student-orientation/incoming-phd/', '3\n']
# ['http://cs.illinois.edu/current-students/new-graduate-student-orientation/incoming-professional-mcs/', '3\n']
# ['http://cs.illinois.edu/current-students/student-organizations/', '-1\n']
# ['http://cs.illinois.edu/current-students/undergraduates/', '-1\n']
# ['http://cs.illinois.edu/current-students/undergraduates/building-access/', '4\n']
# ['http://cs.illinois.edu/current-students/undergraduates/cs-resources-where-turn/', '4\n']
# ['http://cs.illinois.edu/current-students/undergraduates/curriculum-course-selection-and-registration/', '4\n']
# ['http://cs.illinois.edu/current-students/undergraduates/feedback-or-report-problem/', '4\n']
# ['http://cs.illinois.edu/current-students/undergraduates/how-advising-works-computer-science-department/', '4\n']
# ['http://cs.illinois.edu/current-students/undergraduates/policies-and-procedures-0/', '4\n']
# ['http://cs.illinois.edu/current-students/undergraduates/policies-and-procedures-0/honor-code-and-academic-integrity/', '4\n']
# ['http://cs.illinois.edu/current-students/undergraduates/policies-and-procedures-0/policy-graded-material-cs-courses/', '4\n']
# ['http://cs.illinois.edu/current-students/undergraduates/policies-and-procedures-0/undergraduate-honors/', '4\n']
# ['http://cs.illinois.edu/current-students/undergraduates/registration-information/', '4\n']
# ['http://cs.illinois.edu/current-students/undergraduates/requirements-flowcharts/', '4\n']
# ['http://cs.illinois.edu/current-students/undergraduates/senior-thesis-faqs/', '4\n']
# ['http://cs.illinois.edu/current-students/undergraduates/undergraduate-courses/', '4\n']
# ['http://cs.illinois.edu/current-students/undergraduates/undergraduate-curriculum-requirements/', '4\n']
# ['http://cs.illinois.edu/directory/', '-1\n']
# ['http://cs.illinois.edu/directory/faculty/', '-1\n']
# ['http://cs.illinois.edu/directory/faculty/profile/adityagp/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/agha/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/akolla/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/andreask/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/bpbailey/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/caesar/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/cgunter/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/chekuri/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/czhai/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/daf/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/danr/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/dhoiem/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/egunter/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/fischerp/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/garzaran/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/grosu/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/hanj/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/hs1/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/indy/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/jch/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/jeffe/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/jianpeng/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/juliahmr/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/kale/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/kcchang/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/kirlik/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/kkarahal/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/klara/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/lavalle/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/lrs/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/lukeo/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/madhu/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/marinov/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/mcaccamo/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/meseguer/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/mfleck/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/mmp/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/mrebl/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/mssammon/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/padua/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/paris/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/pbg/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/pitt/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/ranjitha/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/rhc/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/rhk/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/rutenbar/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/sadve/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/sariel/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/shj/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/sinhas/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/slazebni/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/snir/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/taoxie/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/torrella/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/vadve/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/vmahesh/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/warnow/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/wfu/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/wgropp/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/wtkramer/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/zaher/', '5\n']
# ['http://cs.illinois.edu/directory/faculty/profile/zilles/', '5\n']
# ['http://cs.illinois.edu/directory/offices-and-contacts/', '6\n']
# ['http://cs.illinois.edu/directory/offices-and-contacts/academic-advising-office/', '6\n']
# ['http://cs.illinois.edu/directory/offices-and-contacts/advancement-office/', '6\n']
# ['http://cs.illinois.edu/directory/offices-and-contacts/business-office/', '6\n']
# ['http://cs.illinois.edu/directory/offices-and-contacts/faculty-support/', '6\n']
# ['http://cs.illinois.edu/directory/offices-and-contacts/office-department-head/', '6\n']
# ['http://cs.illinois.edu/directory/path/agha/', '7\n']
# ['http://cs.illinois.edu/directory/path/caesar/', '7\n']
# ['http://cs.illinois.edu/directory/path/cgunter/', '7\n']
# ['http://cs.illinois.edu/directory/path/chekuri/', '7\n']
# ['http://cs.illinois.edu/directory/path/czhai/', '7\n']
# ['http://cs.illinois.edu/directory/path/daf/', '7\n']
# ['http://cs.illinois.edu/directory/path/danr/', '7\n']
# ['http://cs.illinois.edu/directory/path/dhoiem/', '7\n']
# ['http://cs.illinois.edu/directory/path/dmnicol/', '7\n']
# ['http://cs.illinois.edu/directory/path/garzaran/', '7\n']
# ['http://cs.illinois.edu/directory/path/gropp/', '7\n']
# ['http://cs.illinois.edu/directory/path/hanj/', '7\n']
# ['http://cs.illinois.edu/directory/path/heath/', '7\n']
# ['http://cs.illinois.edu/directory/path/indy/', '7\n']
# ['http://cs.illinois.edu/directory/path/jch/', '7\n']
# ['http://cs.illinois.edu/directory/path/juliahmr/', '7\n']
# ['http://cs.illinois.edu/directory/path/kale/', '7\n']
# ['http://cs.illinois.edu/directory/path/kcchang/', '7\n']
# ['http://cs.illinois.edu/directory/path/kingst/', '7\n']
# ['http://cs.illinois.edu/directory/path/kkarahal/', '7\n']
# ['http://cs.illinois.edu/directory/path/klara/', '7\n']
# ['http://cs.illinois.edu/directory/path/lavalle/', '7\n']
# ['http://cs.illinois.edu/directory/path/lrs/', '7\n']
# ['http://cs.illinois.edu/directory/path/madhu/', '7\n']
# ['http://cs.illinois.edu/directory/path/mcaccamo/', '7\n']
# ['http://cs.illinois.edu/directory/path/meseguer/', '7\n']
# ['http://cs.illinois.edu/directory/path/mmp/', '7\n']
# ['http://cs.illinois.edu/directory/path/padua/', '7\n']
# ['http://cs.illinois.edu/directory/path/paris/', '7\n']
# ['http://cs.illinois.edu/directory/path/pbg/', '7\n']
# ['http://cs.illinois.edu/directory/path/pitt/', '7\n']
# ['http://cs.illinois.edu/directory/path/rhc/', '7\n']
# ['http://cs.illinois.edu/directory/path/rhk/', '7\n']
# ['http://cs.illinois.edu/directory/path/rjohnson/', '7\n']
# ['http://cs.illinois.edu/directory/path/rutenbar/', '7\n']
# ['http://cs.illinois.edu/directory/path/sadve/', '7\n']
# ['http://cs.illinois.edu/directory/path/sariel/', '7\n']
# ['http://cs.illinois.edu/directory/path/shanbhag/', '7\n']
# ['http://cs.illinois.edu/directory/path/shj/', '7\n']
# ['http://cs.illinois.edu/directory/path/sinhas/', '7\n']
# ['http://cs.illinois.edu/directory/path/slazebni/', '7\n']
# ['http://cs.illinois.edu/directory/path/snir/', '7\n']
# ['http://cs.illinois.edu/directory/path/torrella/', '7\n']
# ['http://cs.illinois.edu/directory/path/vadve/', '7\n']
# ['http://cs.illinois.edu/directory/path/wfu/', '7\n']
# ['http://cs.illinois.edu/directory/path/wgropp/', '7\n']
# ['http://cs.illinois.edu/directory/path/whs/', '7\n']
# ['http://cs.illinois.edu/directory/path/winslett/', '7\n']
# ['http://cs.illinois.edu/directory/path/zaher/', '7\n']
# ['http://cs.illinois.edu/directory/path/zilles/', '7\n']
# ['http://cs.illinois.edu/directory/profile/ackrmnn2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/adarnall/', '8\n']
# ['http://cs.illinois.edu/directory/profile/addabbo2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/adeniba1/', '8\n']
# ['http://cs.illinois.edu/directory/profile/adityagp/', '8\n']
# ['http://cs.illinois.edu/directory/profile/agbanusi/', '8\n']
# ['http://cs.illinois.edu/directory/profile/agehret2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/agha/', '8\n']
# ['http://cs.illinois.edu/directory/profile/ajdougla/', '8\n']
# ['http://cs.illinois.edu/directory/profile/ajdunn2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/akolla/', '8\n']
# ['http://cs.illinois.edu/directory/profile/akpande2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/aloving2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/amanfroi/', '8\n']
# ['http://cs.illinois.edu/directory/profile/amwest3/', '8\n']
# ['http://cs.illinois.edu/directory/profile/andreask/', '8\n']
# ['http://cs.illinois.edu/directory/profile/angrave/', '8\n']
# ['http://cs.illinois.edu/directory/profile/anhai/', '8\n']
# ['http://cs.illinois.edu/directory/profile/aoboyle/', '8\n']
# ['http://cs.illinois.edu/directory/profile/aramyan2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/ayong/', '8\n']
# ['http://cs.illinois.edu/directory/profile/bedjeffe/', '8\n']
# ['http://cs.illinois.edu/directory/profile/bergv/', '8\n']
# ['http://cs.illinois.edu/directory/profile/bpbailey/', '8\n']
# ['http://cs.illinois.edu/directory/profile/bradlow/', '8\n']
# ['http://cs.illinois.edu/directory/profile/bwwrigh2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/byi4/', '8\n']
# ['http://cs.illinois.edu/directory/profile/c-heeren/', '8\n']
# ['http://cs.illinois.edu/directory/profile/caesar/', '8\n']
# ['http://cs.illinois.edu/directory/profile/campbell/', '8\n']
# ['http://cs.illinois.edu/directory/profile/carpent/', '8\n']
# ['http://cs.illinois.edu/directory/profile/ccoleman/', '8\n']
# ['http://cs.illinois.edu/directory/profile/cdp/', '8\n']
# ['http://cs.illinois.edu/directory/profile/cgartla2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/cgunter/', '8\n']
# ['http://cs.illinois.edu/directory/profile/chaubey2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/chavosh2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/chekuri/', '8\n']
# ['http://cs.illinois.edu/directory/profile/cjfoster/', '8\n']
# ['http://cs.illinois.edu/directory/profile/clchris2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/clinden2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/cmalkiew/', '8\n']
# ['http://cs.illinois.edu/directory/profile/colinr/', '8\n']
# ['http://cs.illinois.edu/directory/profile/collier3/', '8\n']
# ['http://cs.illinois.edu/directory/profile/croy/', '8\n']
# ['http://cs.illinois.edu/directory/profile/cyang49/', '8\n']
# ['http://cs.illinois.edu/directory/profile/czhai/', '8\n']
# ['http://cs.illinois.edu/directory/profile/daf/', '8\n']
# ['http://cs.illinois.edu/directory/profile/danr/', '8\n']
# ['http://cs.illinois.edu/directory/profile/davis68/', '8\n']
# ['http://cs.illinois.edu/directory/profile/dcarmod2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/dcheek/', '8\n']
# ['http://cs.illinois.edu/directory/profile/dchen/', '8\n']
# ['http://cs.illinois.edu/directory/profile/ddmenon2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/decorray/', '8\n']
# ['http://cs.illinois.edu/directory/profile/deg/', '8\n']
# ['http://cs.illinois.edu/directory/profile/desouzas/', '8\n']
# ['http://cs.illinois.edu/directory/profile/dhoiem/', '8\n']
# ['http://cs.illinois.edu/directory/profile/dig/', '8\n']
# ['http://cs.illinois.edu/directory/profile/djb/', '8\n']
# ['http://cs.illinois.edu/directory/profile/djjung2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/dmnicol/', '8\n']
# ['http://cs.illinois.edu/directory/profile/donnakc/', '8\n']
# ['http://cs.illinois.edu/directory/profile/duursma/', '8\n']
# ['http://cs.illinois.edu/directory/profile/ebohm/', '8\n']
# ['http://cs.illinois.edu/directory/profile/ecaulfi2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/ecfield2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/edk/', '8\n']
# ['http://cs.illinois.edu/directory/profile/egunter/', '8\n']
# ['http://cs.illinois.edu/directory/profile/eheath3/', '8\n']
# ['http://cs.illinois.edu/directory/profile/ekerman/', '8\n']
# ['http://cs.illinois.edu/directory/profile/ekirr/', '8\n']
# ['http://cs.illinois.edu/directory/profile/ellis23/', '8\n']
# ['http://cs.illinois.edu/directory/profile/emduart2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/emerrim2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/erichorn/', '8\n']
# ['http://cs.illinois.edu/directory/profile/erink/', '8\n']
# ['http://cs.illinois.edu/directory/profile/etatum2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/etedadi2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/ewilson/', '8\n']
# ['http://cs.illinois.edu/directory/profile/eyal/', '8\n']
# ['http://cs.illinois.edu/directory/profile/fassina2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/fboca/', '8\n']
# ['http://cs.illinois.edu/directory/profile/fgultepe/', '8\n']
# ['http://cs.illinois.edu/directory/profile/fieldst2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/fischerp/', '8\n']
# ['http://cs.illinois.edu/directory/profile/ford126/', '8\n']
# ['http://cs.illinois.edu/directory/profile/friedman/', '8\n']
# ['http://cs.illinois.edu/directory/profile/fulan2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/gambill/', '8\n']
# ['http://cs.illinois.edu/directory/profile/garzaran/', '8\n']
# ['http://cs.illinois.edu/directory/profile/gdu3/', '8\n']
# ['http://cs.illinois.edu/directory/profile/gfrancis/', '8\n']
# ['http://cs.illinois.edu/directory/profile/girju/', '8\n']
# ['http://cs.illinois.edu/directory/profile/girlea2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/golliver/', '8\n']
# ['http://cs.illinois.edu/directory/profile/golze2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/gondolo2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/gramcko2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/grosu/', '8\n']
# ['http://cs.illinois.edu/directory/profile/gu21/', '8\n']
# ['http://cs.illinois.edu/directory/profile/haddox1/', '8\n']
# ['http://cs.illinois.edu/directory/profile/hakobya2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/hanj/', '8\n']
# ['http://cs.illinois.edu/directory/profile/haosun3/', '8\n']
# ['http://cs.illinois.edu/directory/profile/hbagwell/', '8\n']
# ['http://cs.illinois.edu/directory/profile/hburso2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/heath/', '8\n']
# ['http://cs.illinois.edu/directory/profile/heersin2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/hender/', '8\n']
# ['http://cs.illinois.edu/directory/profile/hirani/', '8\n']
# ['http://cs.illinois.edu/directory/profile/hkim326/', '8\n']
# ['http://cs.illinois.edu/directory/profile/hliu36/', '8\n']
# ['http://cs.illinois.edu/directory/profile/hlzike/', '8\n']
# ['http://cs.illinois.edu/directory/profile/hquan4/', '8\n']
# ['http://cs.illinois.edu/directory/profile/hs1/', '8\n']
# ['http://cs.illinois.edu/directory/profile/huo3/', '8\n']
# ['http://cs.illinois.edu/directory/profile/iahmed8/', '8\n']
# ['http://cs.illinois.edu/directory/profile/ianford2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/iclay/', '8\n']
# ['http://cs.illinois.edu/directory/profile/indy/', '8\n']
# ['http://cs.illinois.edu/directory/profile/inik/', '8\n']
# ['http://cs.illinois.edu/directory/profile/janema2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/jbheller/', '8\n']
# ['http://cs.illinois.edu/directory/profile/jccl/', '8\n']
# ['http://cs.illinois.edu/directory/profile/jch/', '8\n']
# ['http://cs.illinois.edu/directory/profile/jchung50/', '8\n']
# ['http://cs.illinois.edu/directory/profile/jdg5/', '8\n']
# ['http://cs.illinois.edu/directory/profile/jeffe/', '8\n']
# ['http://cs.illinois.edu/directory/profile/jhasegaw/', '8\n']
# ['http://cs.illinois.edu/directory/profile/jhatton/', '8\n']
# ['http://cs.illinois.edu/directory/profile/jianma/', '8\n']
# ['http://cs.illinois.edu/directory/profile/jianpeng/', '8\n']
# ['http://cs.illinois.edu/directory/profile/jiwise2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/jli135/', '8\n']
# ['http://cs.illinois.edu/directory/profile/jlowens/', '8\n']
# ['http://cs.illinois.edu/directory/profile/jlsmith6/', '8\n']
# ['http://cs.illinois.edu/directory/profile/jmwu/', '8\n']
# ['http://cs.illinois.edu/directory/profile/jodwyer/', '8\n']
# ['http://cs.illinois.edu/directory/profile/jpascale/', '8\n']
# ['http://cs.illinois.edu/directory/profile/jpda/', '8\n']
# ['http://cs.illinois.edu/directory/profile/jsapir2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/jscole/', '8\n']
# ['http://cs.illinois.edu/directory/profile/jtpruit2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/juliahmr/', '8\n']
# ['http://cs.illinois.edu/directory/profile/kalbarcz/', '8\n']
# ['http://cs.illinois.edu/directory/profile/kale/', '8\n']
# ['http://cs.illinois.edu/directory/profile/kamin/', '8\n']
# ['http://cs.illinois.edu/directory/profile/karthe/', '8\n']
# ['http://cs.illinois.edu/directory/profile/kbogle/', '8\n']
# ['http://cs.illinois.edu/directory/profile/kcchang/', '8\n']
# ['http://cs.illinois.edu/directory/profile/kesan/', '8\n']
# ['http://cs.illinois.edu/directory/profile/khashab2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/kingst/', '8\n']
# ['http://cs.illinois.edu/directory/profile/kirkory2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/kirlik/', '8\n']
# ['http://cs.illinois.edu/directory/profile/kiyavash/', '8\n']
# ['http://cs.illinois.edu/directory/profile/kkarahal/', '8\n']
# ['http://cs.illinois.edu/directory/profile/klajbor2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/klara/', '8\n']
# ['http://cs.illinois.edu/directory/profile/kmacgreg/', '8\n']
# ['http://cs.illinois.edu/directory/profile/kmkoch3/', '8\n']
# ['http://cs.illinois.edu/directory/profile/kmortens/', '8\n']
# ['http://cs.illinois.edu/directory/profile/kosar2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/koutsak2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/krunck/', '8\n']
# ['http://cs.illinois.edu/directory/profile/kstahl/', '8\n']
# ['http://cs.illinois.edu/directory/profile/kudaliga/', '8\n']
# ['http://cs.illinois.edu/directory/profile/kydonak2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/lavalle/', '8\n']
# ['http://cs.illinois.edu/directory/profile/lescobar/', '8\n']
# ['http://cs.illinois.edu/directory/profile/lfolwa2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/liao28/', '8\n']
# ['http://cs.illinois.edu/directory/profile/lierl/', '8\n']
# ['http://cs.illinois.edu/directory/profile/ligao3/', '8\n']
# ['http://cs.illinois.edu/directory/profile/longfie2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/loui/', '8\n']
# ['http://cs.illinois.edu/directory/profile/lrs/', '8\n']
# ['http://cs.illinois.edu/directory/profile/lschmitt/', '8\n']
# ['http://cs.illinois.edu/directory/profile/ltpham3/', '8\n']
# ['http://cs.illinois.edu/directory/profile/lukeo/', '8\n']
# ['http://cs.illinois.edu/directory/profile/madhu/', '8\n']
# ['http://cs.illinois.edu/directory/profile/madu/', '8\n']
# ['http://cs.illinois.edu/directory/profile/mando/', '8\n']
# ['http://cs.illinois.edu/directory/profile/marinov/', '8\n']
# ['http://cs.illinois.edu/directory/profile/marsha/', '8\n']
# ['http://cs.illinois.edu/directory/profile/mastroe2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/mattox/', '8\n']
# ['http://cs.illinois.edu/directory/profile/mcaccamo/', '8\n']
# ['http://cs.illinois.edu/directory/profile/mctran2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/mdbailey/', '8\n']
# ['http://cs.illinois.edu/directory/profile/meseguer/', '8\n']
# ['http://cs.illinois.edu/directory/profile/mfleck/', '8\n']
# ['http://cs.illinois.edu/directory/profile/mgolpar/', '8\n']
# ['http://cs.illinois.edu/directory/profile/mhellwig/', '8\n']
# ['http://cs.illinois.edu/directory/profile/mif/', '8\n']
# ['http://cs.illinois.edu/directory/profile/mingxiao/', '8\n']
# ['http://cs.illinois.edu/directory/profile/minje/', '8\n']
# ['http://cs.illinois.edu/directory/profile/misailo/', '8\n']
# ['http://cs.illinois.edu/directory/profile/mitras/', '8\n']
# ['http://cs.illinois.edu/directory/profile/mjang10/', '8\n']
# ['http://cs.illinois.edu/directory/profile/mkelley/', '8\n']
# ['http://cs.illinois.edu/directory/profile/mlivesa2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/mmp/', '8\n']
# ['http://cs.illinois.edu/directory/profile/mnb/', '8\n']
# ['http://cs.illinois.edu/directory/profile/moone/', '8\n']
# ['http://cs.illinois.edu/directory/profile/mrebl/', '8\n']
# ['http://cs.illinois.edu/directory/profile/mssammon/', '8\n']
# ['http://cs.illinois.edu/directory/profile/muncast/', '8\n']
# ['http://cs.illinois.edu/directory/profile/murphyrf/', '8\n']
# ['http://cs.illinois.edu/directory/profile/mwellens/', '8\n']
# ['http://cs.illinois.edu/directory/profile/mwoodley/', '8\n']
# ['http://cs.illinois.edu/directory/profile/mzhao16/', '8\n']
# ['http://cs.illinois.edu/directory/profile/n-ahuja/', '8\n']
# ['http://cs.illinois.edu/directory/profile/negrons2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/nhv/', '8\n']
# ['http://cs.illinois.edu/directory/profile/nikita/', '8\n']
# ['http://cs.illinois.edu/directory/profile/nikos/', '8\n']
# ['http://cs.illinois.edu/directory/profile/nirobles/', '8\n']
# ['http://cs.illinois.edu/directory/profile/nzhang28/', '8\n']
# ['http://cs.illinois.edu/directory/profile/ochoade2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/oikhberg/', '8\n']
# ['http://cs.illinois.edu/directory/profile/padua/', '8\n']
# ['http://cs.illinois.edu/directory/profile/palmore/', '8\n']
# ['http://cs.illinois.edu/directory/profile/panagio2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/paris/', '8\n']
# ['http://cs.illinois.edu/directory/profile/pbg/', '8\n']
# ['http://cs.illinois.edu/directory/profile/pdnelso2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/penciak2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/petrckv2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/phierony/', '8\n']
# ['http://cs.illinois.edu/directory/profile/pitt/', '8\n']
# ['http://cs.illinois.edu/directory/profile/pkarimi2/', '8\n']
# ['http://cs.illinois.edu/directory/profile/pynncoa2/', '8\n']
# ...
# ['http://cs.illinois.edu/prospective-students/graduate-students/faqs/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/general-university-and-department-requirements-applicants/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/graduate-recruitment-fairs/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-bioinformatics-program/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-bioinformatics-program/application-deadlines-and-steps-app/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-bioinformatics-program/application-evaluation-process/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-bioinformatics-program/degree-requirements/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-bioinformatics-program/final-application-checklist/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/application-deadlines-and-steps-apply-graduat/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/application-evaluation-process/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/final-application-checklist/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/andrew-shana-laur/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/astar-graduate-sc/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/chirag-foundation/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/cl-and-jane-w-s-l/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/cw-gear-outstandi/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/david-j-kuck-outs/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/dennis-weathersto/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/diffenbaugh-fello/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/dissertation-comp/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/facebook-fellowsh/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/feng-chen-memoria/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/george-michael-me/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/google-phd-fellow/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/graduate-college-/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/illinois-distingu/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/ira-debra-cohen-g/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/mavis-scholarship/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/microsoft-resea-0/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/microsoft-researc/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/national-defense-/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/nsf-graduate-rese/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/nvidia-graduate-f/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/outstanding-teach/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/qualcomm-innovati/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/qualcomm-q-award-/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/ray-ozzie-compute/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/richard-t-cheng-e/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/roy-j-carver-fell/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/saburo-muroga-end/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/samsung-electroni/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/siebel-scholars/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/sohaib-and-sara-a/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/support-under-rep/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/w-j-poppelbaum-me/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/wing-kai-cheng-fe/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/yahoo-key-scienti/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/yahoo-outstanding/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-fellowships-awards/yee-memorial-fund/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/graduate-research/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/ms-phd-programs/ms-and-phd-degree-requirements/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/non-degree-certificate-program/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/places-explore/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/professional-masters-mcs/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/professional-masters-mcs/application-deadlines-and-steps-appl/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/professional-masters-mcs/application-evaluation-process/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/professional-masters-mcs/final-application-checklist/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/professional-masters-mcs/learn-more-about-professional-master/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/professional-masters-mcs/professional-masters-apply-now/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/professional-masters-mcs/professional-masters-campus/', '13\n']
# ['http://cs.illinois.edu/prospective-students/graduate-students/professional-masters-mcs/professional-masters-mcs-degree-requ/', '13\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/', '-1\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/cs-degrees-offered/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/cs-degrees-offered/bs-ms-5-year-program/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/cs-degrees-offered/bs-ms-5-year-program/bs-ms-5-year-program-req/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/cs-degrees-offered/bs-ms-5-year-program/program-requirements/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/cs-degrees-offered/bs-statscomputer-science/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/cs-degrees-offered/cs-college-engineering/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/cs-degrees-offered/cs-minor/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/cs-degrees-offered/cs-x/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/cs-degrees-offered/mathcomputer-science/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/transfer-students/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/transfer-students/transferring-another-university-illinois-major/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-learning-outcomes/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-perspectives/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-research/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/afcea-cyber-studies-schola/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/barry-m-goldwater-scholars/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/bronze-tablet-award/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/channing-brown-scholarship/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/cisco-systems-wcs-undergra/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/cra-outstanding-undergradu/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/crowe-horwath-llp-outstand/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/cw-gear-outstanding-underg/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/daniel-l-slotnick-scholars/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/duncan-h-lawrie-leadership/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/dunn-systems-undergraduate/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/engineering-council-outsta/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/engineering-visionary-scho/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/franz-hohn-and-jp-nash-sch/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/frima-lukatskaya-scholarsh/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/illinois-cyber-security-sc/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/james-n-snyder-memorial-aw/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/jeffrey-p-blahut-memorial-/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/john-deere-scholarship-com/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/john-r-pasta-outstanding-u/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/jump-trading-scholars/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/knight-st-patrick/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/michael-s-hughes-award-sof/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/rockwell-collins-scholarsh/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/rowe-family-scholarship/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/sara-and-louis-cohen-under/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/senior-100-honorary/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/spot-trading-scholarship/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/spyglass-undergraduate-sch/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/state-farm-computer-scienc/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/susan-silver-and-ross-erle/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-and-awards/william-and-ruth-witt-scho/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/undergraduate-scholarships-awards/', '14\n']
# ['http://cs.illinois.edu/prospective-students/undergraduates/why-computer-science-illinois/', '14\n']
# ['http://cs.illinois.edu/research/', '-1\n']
# ['http://cs.illinois.edu/research/architecture-compilers-and-parallel-computing/', '15\n']
# ['http://cs.illinois.edu/research/areas/scientific/', '15\n']
# ['http://cs.illinois.edu/research/artificial-intelligence/', '15\n']
# ['http://cs.illinois.edu/research/bioinformatics-and-computational-biology/', '15\n']
# ['http://cs.illinois.edu/research/database-and-information-systems/', '15\n']
# ['http://cs.illinois.edu/research/database-and-information-systems/information-network-academic-research-center/', '15\n']
# ['http://cs.illinois.edu/research/graphics-visualization-and-human-computer-interaction/', '15\n']
# ['http://cs.illinois.edu/research/programming-languages-formal-methods-and-software-engineering/', '15\n']
# ['http://cs.illinois.edu/research/research-areas/', '15\n']
# ['http://cs.illinois.edu/research/research-centers/', '15\n']
# ['http://cs.illinois.edu/research/scientific-computing/', '15\n']
# ['http://cs.illinois.edu/research/systems-and-networking/', '15\n']
# ['http://cs.illinois.edu/research/theory-and-algorithms/', '15\n']
# ['http://cs.illinois.edu/site-map/', '-1\n']
# ['http://cs.illinois.edu/staff-positions/', '-1\n']
# ['http://cs.illinois.edu/why-give/', '-1\n']
# ['http://cs.illinois.edu/www.cattell.net/rick/index.html/', '-1\n']
# ['http://cs.illinois.edu/www.cse.ohio-state.edu/~teodores/', '-1\n']
# ['http://cs.illinois.edu/www.ec.illinois.edu/inv/societies.php/', '-1\n']
# ['http://www.cs.illinois.edu/~slazebni/', '-1\n']
# ['http://www.cs.illinois.edu/homes/czhai/', '-1\n']

# %% [markdown]
# ### TFIDF Matrix
# Term frequency - inverse document frequency (tf-idf) vectorizer parameters.
# To get a Tf-idf matrix, first count word occurrences by document. This is transformed into a document-term matrix (dtm). This is also just called a term frequency matrix.
#
# ![Alt text](http://www.codeproject.com/KB/WPF/NNMFSearchResultClusterin/table.jpg "DTM")
#
# Then apply the term frequency-inverse document frequency weighting: words that occur frequently within a document but not frequently within the corpus receive a higher weighting as these words are assumed to contain more meaning in relation to the document.
#
# Parameters defined below:
#
# **max_df**: this is the maximum frequency within the documents a given feature can have to be used in the tfi-idf matrix. If the term is in greater than 80% of the documents it probably cares little meanining (in the context of film synopses)
#
# **min_idf**: this could be an integer (e.g. 5) and the term would have to be in at least 5 of the documents to be considered. Here I pass 0.2; the term must be in at least 20% of the document. I found that if I allowed a lower min_df I ended up basing clustering on names--for example "Michael" or "Tom" are names found in several of the movies and the synopses use these names frequently, but the names carry no real meaning.
#
# **ngram_range**: this just means I'll look at unigrams, bigrams and trigrams. See n-grams

# %%
# TFIDF vectorizer
tfidf_vectorizer = TfidfVectorizer(
    max_df = 0.8,
    max_features = 200000,
    min_df = 0.1,
    stop_words = 'english',
    use_idf = True,
    tokenizer = tokenize_and_stem,
    ngram_range = (1,3)
)

"""TFIDF matrix No-Costraint"""
tfidf_matrix_nc = tfidf_vectorizer.fit_transform(pages_content_nc)

"""TFIDF matrix List-Costraint"""
tfidf_matrix_lc = tfidf_vectorizer.fit_transform(pages_content_lc)

# %% [markdown]
# ### Cosine Similarity
# dist is defined as 1 - the cosine similarity of each document. Cosine similarity is measured against the tf-idf matrix and can be used to generate a measure of similarity between each document and the other documents in the corpus

# %%
"""No-Costraint"""
dist_nc = 1 - cosine_similarity(tfidf_matrix_nc)

"""List-Costraint"""
dist_lc = 1 - cosine_similarity(tfidf_matrix_lc)

# %% [markdown]
# ### Word2Vec
# Applying word2vec (skip-gram with negative sampling) to sequences generated by crawling the web site. Vectors generated for each web-page are stored in **w2v_vecs_nc** and **w2v_vecs_lc**

# %%
"""No-Costraint"""
sequences_nc = nocostraint_path + "sequenceIDs.txt"

# because of generator
vocab_sequences_nc = get_seq(sequences_nc, 1)
train_sequences_nc = get_seq(sequences_nc, 1)

"""List-Costraint"""
sequences_lc = listcostraint_path + "sequenceIDs.txt"

# because of generator
vocab_sequences_lc = get_seq(sequences_lc, 1)
train_sequences_lc = get_seq(sequences_lc, 1)

# %%
"""No-Costraint"""
w2v_model_nc = Word2Vec(min_count=1, negative=5, size=48)
w2v_model_nc.build_vocab(vocab_sequences_nc)
w2v_model_nc.train(train_sequences_nc)

w2v_vecs_nc = np.array([w2v_model_nc[key] for key in content_nc_map])

"""List-Costraint"""
w2v_model_lc = Word2Vec(min_count=1, negative=5, size=48)
w2v_model_lc.build_vocab(vocab_sequences_lc)
w2v_model_lc.train(train_sequences_lc)

w2v_vecs_lc = np.array([w2v_model_lc[key] for key in content_lc_map])

# %% [markdown]
# ### Latent Semantic Analysis (LSA)
# Dimensionality reduction using **truncated SVD** (aka LSA).
# This transformer performs linear dimensionality reduction by means of truncated singular value decomposition (SVD).
#
# It is very similar to PCA, but operates on sample vectors directly, instead of on a covariance matrix.
#
# In particular, truncated SVD works on term count/tf-idf matrices as returned by the vectorizers. In that context, it is known as latent semantic analysis (LSA).

# %%
svd = TruncatedSVD(n_components=50, algorithm="arpack", random_state=1)

"""No-Costraint"""
pages_tfidf_vecs_nc = svd.fit_transform(tfidf_matrix_nc)

"""List-Costraint"""
pages_tfidf_vecs_lc = svd.fit_transform(tfidf_matrix_lc)

# %% [markdown]
# ### Combining Vectors from word2vec and TFIDF
# Appending TFIDF vector at the end of the relative word2vec vector for each page.

# %%
"""No-Costraint"""
combined_vecs_nc = [np.append(w2v_vecs_nc[i], pages_tfidf_vecs_nc[i]) for i in range(len(pages_tfidf_vecs_nc))]

"""List-Costraint"""
combined_vecs_lc = [np.append(w2v_vecs_lc[i], pages_tfidf_vecs_lc[i]) for i in range(len(pages_tfidf_vecs_lc))]

# %% [markdown]
# ### T-SNE
# Reducing vectors dimensionality to 2 for plot purposes

# %%
tsne = TSNE(n_components=2, random_state=1)

"""No-Costraint"""
twodim_nc = tsne.fit_transform(combined_vecs_nc)

"""List-Costraint"""
twodim_lc = tsne.fit_transform(combined_vecs_lc)

# %% [markdown]
# ### K-Means Clustering

# %%
kmeans = KMeans(n_clusters=15)

"""No-Costraint"""
kmeans.fit(tfidf_matrix_nc)
kmeans_clusters_nc = kmeans.labels_
kmeans_colors_nc = [get_color(i) for i in kmeans_clusters_nc]

"""List-Costraint"""
kmeans.fit(tfidf_matrix_lc)
kmeans_clusters_lc = kmeans.labels_
kmeans_colors_lc = [get_color(i) for i in kmeans_clusters_lc]

# %% [markdown]
# ### K-Means No-costraint plot

# %%
kmeans_data_nc = scatter_plot(twodim_nc, word_labels=longurls_nc, colors=kmeans_colors_nc)
py.iplot(kmeans_data_nc, filename="K-Means TFIDF-W2V Clustering - No-Costraint")

# %% [markdown]
# ### K-Means List-costraint plot

# %%
kmeans_data_lc = scatter_plot(twodim_lc, word_labels=longurls_lc, colors=kmeans_colors_lc)
py.iplot(kmeans_data_lc, filename="K-Means TFIDF-W2V Clustering - List-Costraint")

# %% [markdown]
# ### HDBSCAN Clsustering

# %%
hdbscan = HDBSCAN(min_cluster_size=7)

"""No-Costraint"""
hdbscan_labels_nc = hdbscan.fit_predict(tfidf_matrix_nc)
hdbscan_colors_nc = [get_color(n_clust) for n_clust in hdbscan_labels_nc]

print "Clusters found with HDBSCAN in No-costraint Dataset:", len(set(hdbscan_labels_nc))
print [label for label in set(hdbscan_labels_nc)], "\n"

"""List-Costraint"""
hdbscan_labels_lc = hdbscan.fit_predict(tfidf_matrix_lc)
hdbscan_colors_lc = [get_color(n_clust) for n_clust in hdbscan_labels_lc]

print "Clusters found with HDBSCAN in List-costraint Dataset:", len(set(hdbscan_labels_nc))
print [label for label in set(hdbscan_labels_nc)]

# %% [markdown]
# ### HDBSCAN No-costraint plot

# %%
hdbscan_data_nc = scatter_plot(twodim_nc, word_labels=longurls_nc, colors=hdbscan_colors_nc)
py.iplot(hdbscan_data_nc, filename="HDBSCAN TFIDF-W2V Clustering - No-Costraint")

# %% [markdown]
# ### HDBSCAN List-costraint plot

# %%
hdbscan_data_lc = scatter_plot(twodim_lc, word_labels=longurls_lc, colors=hdbscan_colors_lc)
py.iplot(hdbscan_data_lc, filename="HDBSCAN TFIDF-W2V Clustering - List-Costraint")

# %%
print(len(hdbscan_labels_lc))

# %%
real_membership_list = real_membership_lc
clusters_found_labels = hdbscan_labels_lc

conf_table = np.zeros((len(set(real_membership_list)), len(set(clusters_found_labels))), dtype="int8")
real_clusters_set = set(real_membership_list)

assert isinstance(real_membership_list[0], int), "Type is not int"
assert isinstance(clusters_found_labels[0], int), "Type is not int"

for current_clust in real_clusters_set:
        for i in range(len(clusters_found_labels)):
            if int(real_membership_list[i]) == int(current_clust):
                cluster_found = clusters_found_labels[i]
                conf_table[current_clust][cluster_found] = 1 # conf_table[current_clust][cluster_found] + 1

# %%
real_membership_lc = [int(m) for m in real_membership_lc]
print (set(real_membership_lc))

# %%
get_confusion_table(real_membership_lc ,hdbscan_labels_lc)

# %%
"""from sklearn.manifold import TSNE
import numpy as np
X = np.random.rand(100,100)
t = TSNE(n_components=20)
t.fit(X)"""
